# %% [markdown]
# # L'algorithme OMP - Principe de fonctionnement

# %% [markdown]
# Ce notebook a pour but de présenter une utilisation possible de l'algorithme OMP. D'un point de vue théorique, l'algorithme OMP vise à trouver la meilleure approximation sparse d'un vecteur $x$ à partir d'un dictionnaire $D$ donné. Mathématiquement, on cherche à résoudre en $\gamma$ le problème d'optimisation suivant:
# $$\min_\gamma \left||x - D\gamma \right||_{2}^{2}$$
# sous la contrainte que tous les éléments de $\gamma$ sont soit nuls soit égaux à 1 et que:
# $$\sum_{i = 1}^{n} \gamma _i \leq K$$
# avec $K$ le nombre maximal de features du dictionnaire $D$ présentes dans le vecteur $x$.
#
# Dans notre cas, le vecteur $x$ sera représenté par une image pouvant contenir plusieurs formes géométriques. L'ensemble des formes géométriques se stocké dans le dictionnaire et nous verront comment les retrouver avec l'implémentation de l'algorithme OMP que propose scikit-learn.

# %% [markdown]
# ## Génération du dictionnaire

# %% [markdown]
# Commençons, à l'aide de la bibliothèqe scikit-image, par générer quelques formes géométriques...

# %%
import numpy as np
from skimage.draw import circle_perimeter, ellipse_perimeter, polygon, line

# %%
cercle = np.zeros((10, 10), np.uint8)
cercle[circle_perimeter(4, 4, 3)] = 1

ellipse = np.zeros((10, 10), np.uint8)
ellipse[ellipse_perimeter(4, 4, 3, 5)] = 1

square = np.zeros((10, 10), np.uint8)
square[polygon(np.array([1, 4, 4, 1]), np.array([1, 1, 4, 4]))] = 1

dline = np.zeros((10, 10), np.uint8)
dline[line(1, 1, 8, 8)] = 1

shapes = [cercle, ellipse, square, dline]

# %% [markdown]
# Une petite représentation graphique de l'une des formes ci-dessus...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(cercle, cmap='gray')
plt.title("Un cercle obtenu avec scikit-image")

# %% [markdown]
# Il ne reste plus qu'à constituer le dictionnaire:

# %%
D = np.zeros((100, 4))

for i in range(len(shapes)):
    D[:,i] = shapes[i].ravel()
    D[:,i] = D[:,i]/np.linalg.norm(D[:,i])

# %% [markdown]
# ## Fonction génératrice d'images

# %% [markdown]
# On définit une fonction permettant de générer une combinaison aléatoire des signaux images regroupés dans notre dictionnaire.

# %%
import random

# %%
def generate_img(i):
    """generates combination of i shapes from D dictionnary"""
    output = np.zeros(100)
    for _ in range(i):
        output += D[:,random.randint(0, len(shapes)-1)]
    return output

# %% [markdown]
# Quelques démonstrations...

# %%
plt.imshow(generate_img(1).reshape((10, 10)), cmap='gray')
#dline

# %%
plt.imshow(generate_img(2).reshape((10, 10)), cmap='gray')
#ellispe + carré

# %% [markdown]
# ## Utilisation de l'algorithme OMP

# %%
from sklearn.linear_model import orthogonal_mp

# %% [markdown]
# A partir du moment où l'on a identifié les signaux utilisés dans l'image à analyser, on peut en déduire les formes géométriques présentes dans l'image. C'est ce que fait la fonction ci-dessous.

# %%
shapes_names = np.array(['circle', 'ellipse', 'square', 'line'])

def recognize(img, n_coefs):
    gamma = orthogonal_mp(D, img, n_nonzero_coefs = n_coefs)
    plt.imshow(img.reshape((10, 10)), cmap = 'gray')
    return shapes_names[gamma.astype('bool')]

# %% [markdown]
# Quelques exemples pour finir...
# Remarque: parfois la fonction génératrice d'images peut choisir deux fois le même signaux, on peut donc avoir un nombre de formes inférieur à $n$.

# %%
n = 1
recognize(generate_img(n), n)
# Out:
# array(['circle'],
#       dtype='|S7')

# %%
n = 2
recognize(generate_img(n), n)
# Out:
# array(['circle', 'square'],
#       dtype='|S7')

# %%
n = 3
recognize(generate_img(n), n)
# Out:
# array(['circle', 'ellipse', 'square'],
#       dtype='|S7')

# %% [markdown]
# ## Une petite démonstration de notre algorithme K-SVD !

# %% [markdown]
# Grâce à l'algorithme OMP, on est bien en mesure de retrouver les signaux utilisés pour construire une image. Tout le challenge consiste donc pour nous, à partir d'un certain nombre d'images à construire un dictionnaire de signaux aussi pertinent que possible. C'est là qu'intervient l'algorithme K-SVD !

# %%
import imp
ksvd = imp.load_source('ksvd', '../Source/ksvd.py')

# %% [markdown]
# On construit une grosse matrice avec pleins d'images comme ci-dessus mais toujours avec deux symboles pour corser un peu les choses !

# %%
X = []
for _ in range(500):
    X.append(generate_img(2))
X = np.array(X).T

# %% [markdown]
# On construit à partir de cette matrcie un dictionnaire grâce à notre implémentation de la classe KSVD

# %%
model = ksvd.KSVD((100, 4), K = 2, n_iter=400)
model.fit(X)
# Out:
# Training dictionary over 400 iterations
#  [                  1%                  ] 7 of 400 complete in 0.6 sec
#  [-                 3%                  ] 13 of 400 complete in 1.2 sec
#  [-                 4%                  ] 19 of 400 complete in 1.7 sec
#  [--                6%                  ] 25 of 400 complete in 2.3 sec
#  [--                7%                  ] 31 of 400 complete in 2.9 sec
#  [---               9%                  ] 37 of 400 complete in 3.5 sec
#  [----             10%                  ] 43 of 400 complete in 4.1 sec
#  [----             12%                  ] 49 of 400 complete in 4.6 sec
#  [-----            13%                  ] 55 of 400 complete in 5.2 sec
#  [-----            15%                  ] 61 of 400 complete in 5.8 sec
#  [------           16%                  ] 67 of 400 complete in 6.4 sec
#  [------           18%                  ] 73 of 400 complete in 7.0 sec
#  [-------          19%                  ] 79 of 400 complete in 7.6 sec
#  [--------         21%                  ] 85 of 400 complete in 8.1 sec
#  [--------         22%                  ] 91 of 400 complete in 8.7 sec
#  [---------        24%                  ] 97 of 400 complete in 9.3 sec
#  [---------        25%                  ] 103 of 400 complete in 9.9 sec
#  [----------       27%                  ] 109 of 400 complete in 10.5 sec
#  [----------       28%                  ] 115 of 400 complete in 11.0 sec
#  [-----------      30%                  ] 121 of 400 complete in 11.6 sec
#  [------------     31%                  ] 127 of 400 complete in 12.2 sec
#  [------------     33%                  ] 133 of 400 complete in 12.8 sec
#  [-------------    34%                  ] 139 of 400 complete in 13.4 sec
#  [-------------    36%                  ] 145 of 400 complete in 13.9 sec
#  [--------------   37%                  ] 151 of 400 complete in 14.5 sec
#  [--------------   39%                  ] 157 of 400 complete in 15.1 sec
#  [---------------  40%                  ] 163 of 400 complete in 15.7 sec
#  [---------------- 42%                  ] 169 of 400 complete in 16.3 sec
#  [---------------- 43%                  ] 175 of 400 complete in 16.8 sec
#  [-----------------45%                  ] 181 of 400 complete in 17.4 sec
#  [-----------------46%                  ] 187 of 400 complete in 18.0 sec
#  [-----------------48%                  ] 193 of 400 complete in 18.6 sec
#  [-----------------49%                  ] 199 of 400 complete in 19.1 sec
#  [-----------------51%                  ] 205 of 400 complete in 19.6 sec
#  [-----------------52%                  ] 211 of 400 complete in 20.2 sec
#  [-----------------54%                  ] 217 of 400 complete in 20.7 sec
#  [-----------------55%-                 ] 223 of 400 complete in 21.3 sec
#  [-----------------57%-                 ] 229 of 400 complete in 21.8 sec
#  [-----------------58%--                ] 235 of 400 complete in 22.4 sec
#  [-----------------60%--                ] 241 of 400 complete in 22.9 sec
#  [-----------------61%---               ] 247 of 400 complete in 23.5 sec
#  [-----------------63%----              ] 253 of 400 complete in 24.0 sec
#  [-----------------64%----              ] 259 of 400 complete in 24.6 sec
#  [-----------------66%-----             ] 265 of 400 complete in 25.1 sec
#  [-----------------67%-----             ] 271 of 400 complete in 25.7 sec
#  [-----------------69%------            ] 277 of 400 complete in 26.2 sec
#  [-----------------70%------            ] 283 of 400 complete in 26.8 sec
#  [-----------------72%-------           ] 289 of 400 complete in 27.3 sec
#  [-----------------73%--------          ] 295 of 400 complete in 27.9 sec
#  [-----------------75%--------          ] 301 of 400 complete in 28.4 sec
#  [-----------------76%---------         ] 307 of 400 complete in 29.0 sec
#  [-----------------78%---------         ] 313 of 400 complete in 29.5 sec
#  [-----------------79%----------        ] 319 of 400 complete in 30.1 sec
#  [-----------------81%----------        ] 325 of 400 complete in 30.6 sec
#  [-----------------82%-----------       ] 331 of 400 complete in 31.2 sec
#  [-----------------84%------------      ] 337 of 400 complete in 31.7 sec
#  [-----------------85%------------      ] 343 of 400 complete in 32.3 sec
#  [-----------------87%-------------     ] 349 of 400 complete in 32.8 sec
#  [-----------------88%-------------     ] 355 of 400 complete in 33.4 sec
#  [-----------------90%--------------    ] 361 of 400 complete in 33.9 sec
#  [-----------------91%--------------    ] 367 of 400 complete in 34.5 sec
#  [-----------------93%---------------   ] 373 of 400 complete in 35.0 sec
#  [-----------------94%----------------  ] 379 of 400 complete in 35.6 sec
#  [-----------------96%----------------  ] 385 of 400 complete in 36.1 sec
#  [-----------------97%----------------- ] 391 of 400 complete in 36.7 sec
#  [-----------------99%----------------- ] 397 of 400 complete in 37.2 sec
#  [-----------------100%-----------------] 400 of 400 complete in 37.6 sec
#    Done!

# %% [markdown]
# Et on représente les atoms du dictionnaire obtenu!

# %%
plt.figure(figsize=(12, 12))

for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.imshow(model.D[:,i].reshape((10,10)), cmap = 'gray')
    plt.title(u"Feature n°{}".format(i+1))

# %% [markdown]
# Et quelques exemples de la façon dont on parvient à reconstituer des images à l'aide de leur décomposition sparse, issue du dictionnaire préceddement obtenu.

# %%
gamma = model.sparse_rep(X)

plt.figure(figsize=(10, 25))
for i in range(5):
        plt.subplot(5, 2, i*2 + 1)
        plt.imshow(X[:,i].reshape((10,10)), cmap = 'gray')
        plt.title("Original image")
        plt.subplot(5, 2, i*2 + 2)
        plt.imshow(model.D.dot(gamma[:,i]).reshape((10,10)), cmap = 'gray')
        plt.title("Sparse representation")

# %% [markdown]
# Trop beau pour être vrai? L'algorithme retrouve parfaitement les images avec lesquelles a été constituée la matrice donc nous avons triché? Un peu... Essayons par souci d'honnêteté intellectuelle de refaire la même opération mais en mettant 2 et oarfois 3 des images de base dans les images de la matrice:

# %%
X = []
for _ in range(250):
    X.append(generate_img(2))
for _ in range(250):
    X.append(generate_img(3))
X = np.array(X).T

# %%
model = ksvd.KSVD((100, 4), K = 3, n_iter=500)
model.fit(X)
# Out:
# Training dictionary over 500 iterations
#  [                  1%                  ] 6 of 500 complete in 0.6 sec
#  [                  2%                  ] 10 of 500 complete in 1.2 sec
#  [-                 2%                  ] 14 of 500 complete in 1.7 sec
#  [-                 3%                  ] 18 of 500 complete in 2.2 sec
#  [-                 4%                  ] 22 of 500 complete in 2.7 sec
#  [-                 5%                  ] 26 of 500 complete in 3.2 sec
#  [--                6%                  ] 30 of 500 complete in 3.8 sec
#  [--                6%                  ] 34 of 500 complete in 4.3 sec
#  [--                7%                  ] 38 of 500 complete in 4.8 sec
#  [---               8%                  ] 42 of 500 complete in 5.3 sec
#  [---               9%                  ] 46 of 500 complete in 5.9 sec
#  [---              10%                  ] 50 of 500 complete in 6.4 sec
#  [----             10%                  ] 54 of 500 complete in 6.9 sec
#  [----             11%                  ] 58 of 500 complete in 7.4 sec
#  [----             12%                  ] 62 of 500 complete in 8.0 sec
#  [-----            13%                  ] 66 of 500 complete in 8.5 sec
#  [-----            14%                  ] 70 of 500 complete in 9.0 sec
#  [-----            14%                  ] 74 of 500 complete in 9.5 sec
#  [-----            15%                  ] 78 of 500 complete in 10.1 sec
#  [------           16%                  ] 82 of 500 complete in 10.6 sec
#  [------           17%                  ] 86 of 500 complete in 11.1 sec
#  [------           18%                  ] 90 of 500 complete in 11.6 sec
#  [-------          18%                  ] 94 of 500 complete in 12.2 sec
#  [-------          19%                  ] 98 of 500 complete in 12.7 sec
#  [-------          20%                  ] 102 of 500 complete in 13.2 sec
#  [--------         21%                  ] 106 of 500 complete in 13.7 sec
#  [--------         22%                  ] 110 of 500 complete in 14.2 sec
#  [--------         22%                  ] 114 of 500 complete in 14.8 sec
#  [--------         23%                  ] 118 of 500 complete in 15.3 sec
#  [---------        24%                  ] 122 of 500 complete in 15.8 sec
#  [---------        25%                  ] 126 of 500 complete in 16.3 sec
#  [---------        26%                  ] 130 of 500 complete in 16.9 sec
#  [----------       26%                  ] 134 of 500 complete in 17.4 sec
#  [----------       27%                  ] 138 of 500 complete in 17.9 sec
#  [----------       28%                  ] 142 of 500 complete in 18.4 sec
#  [-----------      29%                  ] 146 of 500 complete in 19.0 sec
#  [-----------      30%                  ] 150 of 500 complete in 19.5 sec
#  [-----------      30%                  ] 154 of 500 complete in 20.1 sec
#  [------------     31%                  ] 158 of 500 complete in 20.6 sec
#  [------------     32%                  ] 162 of 500 complete in 21.1 sec
#  [------------     33%                  ] 166 of 500 complete in 21.7 sec
#  [------------     34%                  ] 170 of 500 complete in 22.2 sec
#  [-------------    34%                  ] 174 of 500 complete in 22.7 sec
#  [-------------    35%                  ] 178 of 500 complete in 23.3 sec
#  [-------------    36%                  ] 182 of 500 complete in 23.8 sec
#  [--------------   37%                  ] 186 of 500 complete in 24.3 sec
#  [--------------   38%                  ] 190 of 500 complete in 24.9 sec
#  [--------------   38%                  ] 194 of 500 complete in 25.4 sec
#  [---------------  39%                  ] 198 of 500 complete in 25.9 sec
#  [---------------  40%                  ] 202 of 500 complete in 26.5 sec
#  [---------------  41%                  ] 206 of 500 complete in 27.0 sec
#  [---------------  42%                  ] 210 of 500 complete in 27.5 sec
#  [---------------- 42%                  ] 214 of 500 complete in 28.1 sec
#  [---------------- 43%                  ] 218 of 500 complete in 28.6 sec
#  [---------------- 44%                  ] 222 of 500 complete in 29.1 sec
#  [-----------------45%                  ] 226 of 500 complete in 29.7 sec
#  [-----------------46%                  ] 230 of 500 complete in 30.2 sec
#  [-----------------46%                  ] 234 of 500 complete in 30.7 sec
#  [-----------------47%                  ] 238 of 500 complete in 31.3 sec
#  [-----------------48%                  ] 242 of 500 complete in 31.8 sec
#  [-----------------49%                  ] 246 of 500 complete in 32.3 sec
#  [-----------------50%                  ] 250 of 500 complete in 32.9 sec
#  [-----------------50%                  ] 254 of 500 complete in 33.4 sec
#  [-----------------51%                  ] 258 of 500 complete in 33.9 sec
#  [-----------------52%                  ] 262 of 500 complete in 34.5 sec
#  [-----------------53%                  ] 266 of 500 complete in 35.0 sec
#  [-----------------54%                  ] 270 of 500 complete in 35.5 sec
#  [-----------------54%                  ] 274 of 500 complete in 36.0 sec
#  [-----------------55%-                 ] 278 of 500 complete in 36.6 sec
#  [-----------------56%-                 ] 282 of 500 complete in 37.1 sec
#  [-----------------57%-                 ] 286 of 500 complete in 37.6 sec
#  [-----------------58%--                ] 290 of 500 complete in 38.2 sec
#  [-----------------58%--                ] 294 of 500 complete in 38.7 sec
#  [-----------------59%--                ] 298 of 500 complete in 39.2 sec
#  [-----------------60%--                ] 302 of 500 complete in 39.8 sec
#  [-----------------61%---               ] 306 of 500 complete in 40.3 sec
#  [-----------------62%---               ] 310 of 500 complete in 40.8 sec
#  [-----------------62%---               ] 314 of 500 complete in 41.5 sec
#  [-----------------63%----              ] 318 of 500 complete in 42.1 sec
#  [-----------------64%----              ] 322 of 500 complete in 42.8 sec
#  [-----------------65%----              ] 326 of 500 complete in 43.4 sec
#  [-----------------66%-----             ] 330 of 500 complete in 44.0 sec
#  [-----------------66%-----             ] 334 of 500 complete in 44.5 sec
#  [-----------------67%-----             ] 338 of 500 complete in 45.1 sec
#  [-----------------68%-----             ] 342 of 500 complete in 45.6 sec
#  [-----------------69%------            ] 346 of 500 complete in 46.1 sec
#  [-----------------70%------            ] 350 of 500 complete in 46.6 sec
#  [-----------------70%------            ] 354 of 500 complete in 47.2 sec
#  [-----------------71%-------           ] 358 of 500 complete in 47.7 sec
#  [-----------------72%-------           ] 362 of 500 complete in 48.2 sec
#  [-----------------73%-------           ] 366 of 500 complete in 48.7 sec
#  [-----------------74%--------          ] 370 of 500 complete in 49.3 sec
#  [-----------------74%--------          ] 374 of 500 complete in 49.8 sec
#  [-----------------75%--------          ] 378 of 500 complete in 50.3 sec
#  [-----------------76%---------         ] 382 of 500 complete in 50.8 sec
#  [-----------------77%---------         ] 386 of 500 complete in 51.3 sec
#  [-----------------78%---------         ] 390 of 500 complete in 51.9 sec
#  [-----------------78%---------         ] 394 of 500 complete in 52.4 sec
#  [-----------------79%----------        ] 398 of 500 complete in 52.9 sec
#  [-----------------80%----------        ] 402 of 500 complete in 53.4 sec
#  [-----------------81%----------        ] 406 of 500 complete in 54.0 sec
#  [-----------------82%-----------       ] 410 of 500 complete in 54.5 sec
#  [-----------------82%-----------       ] 414 of 500 complete in 55.0 sec
#  [-----------------83%-----------       ] 418 of 500 complete in 55.5 sec
#  [-----------------84%------------      ] 422 of 500 complete in 56.1 sec
#  [-----------------85%------------      ] 426 of 500 complete in 56.6 sec
#  [-----------------86%------------      ] 430 of 500 complete in 57.1 sec
#  [-----------------86%------------      ] 434 of 500 complete in 57.6 sec
#  [-----------------87%-------------     ] 438 of 500 complete in 58.2 sec
#  [-----------------88%-------------     ] 442 of 500 complete in 58.7 sec
#  [-----------------89%-------------     ] 446 of 500 complete in 59.2 sec
#  [-----------------90%--------------    ] 450 of 500 complete in 59.7 sec
#  [-----------------90%--------------    ] 454 of 500 complete in 60.2 sec
#  [-----------------91%--------------    ] 458 of 500 complete in 60.8 sec
#  [-----------------92%---------------   ] 462 of 500 complete in 61.3 sec
#  [-----------------93%---------------   ] 466 of 500 complete in 61.8 sec
#  [-----------------94%---------------   ] 470 of 500 complete in 62.3 sec
#  [-----------------94%----------------  ] 474 of 500 complete in 62.9 sec
#  [-----------------95%----------------  ] 478 of 500 complete in 63.4 sec
#  [-----------------96%----------------  ] 482 of 500 complete in 63.9 sec
#  [-----------------97%----------------  ] 486 of 500 complete in 64.4 sec
#  [-----------------98%----------------- ] 490 of 500 complete in 65.0 sec
#  [-----------------98%----------------- ] 494 of 500 complete in 65.5 sec
#  [-----------------99%----------------- ] 498 of 500 complete in 66.0 sec
#  [-----------------100%-----------------] 500 of 500 complete in 66.4 sec
#    Done!

# %%
plt.figure(figsize=(12, 12))

for i in range(4):
    plt.subplot(2, 2, i+1)
    plt.imshow(model.D[:,i].reshape((10,10)), cmap = 'gray')
    plt.title(u"Feature n°{}".format(i+1))

# %% [markdown]
# Ce n'est pas si mal mais c'est un peu moins bien (on peut dire que le problème était sans doute plus difficile). Voyons tout de même comment sont reconstituées les images:

# %%
gamma = model.sparse_rep(X)

plt.figure(figsize=(10, 25))
for i in range(5):
        plt.subplot(5, 2, i*2 + 1)
        plt.imshow(X[:,i].reshape((10,10)), cmap = 'gray')
        plt.title("Original image")
        plt.subplot(5, 2, i*2 + 2)
        plt.imshow(model.D.dot(gamma[:,i]).reshape((10,10)), cmap = 'gray')
        plt.title("Sparse representation")

# %% [markdown]
# Très correct non ?
#
# Tant que j'y pense, choses qu'il pourrait être intéressant de faire avec les tests sur les images générées:
# - jusqu'à quand augmenter le nombre d'itérations permet-il de gagner en précision?
# - quel dictionnaire pour initialiser le dictionnaire ?
