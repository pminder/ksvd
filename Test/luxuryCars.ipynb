# %% [markdown]
# # K-SVD et voitures de luxe...

# %% [markdown]
# Ce notebook se présente comme une proof of concept de l'utilisation que l'on peut faire du traitement des images par représentation sparse en général et de l'algorithme k-svd en particulier.
#
# La méthode utilisée est la suivante:
# - on crée un dictionnaire à partir d'une base de données initiales constituée de petites images (ou patchs) issus d'une séri d'images représentant des voitures de luxe
# - on choisit une image nouvelle image de voiture sur internet que l'on bruite artificiellement
# - on calcule ensuite sa représentation sparse grâce à un algorithme du type batch-OMP et on voit ce que ça donne !

# %% [markdown]
# ## Constitution de la base d'entraînement

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
# %matplotlib inline

# %%
path2db = "../Database/Cars/"

# %% [markdown]
# Un exemple d'image au hasard, juste pour ce faire une idée:

# %%
imgs = !ls $path2db
plt.imshow(plt.imread(path2db+imgs[1]))
plt.title("Un exemple de voiture")

# %% [markdown]
# ### Fonction pour redimensioner les images

# %% [markdown]
# Sans cette fonction, on risque de générer trop de patchs. Dans un premier temps, je préfère diminuer un peu la taille des images. On verra ensuite si on peut lever cette restriction.

# %%
from skimage.transform import rescale

# %%
def resize_car(img):
    """Allow at most images of size (150, 150)"""
    x, y = img.shape[0], img.shape[1]
    if max(x, y) > 150:
        l = 150./max(x,y)
        img = rescale(img, l)
    return img

# %% [markdown]
# ### Division en patchs

# %%
def div_patchs(img, patch_dim = (8, 8), gray = True):
    """Return a 2d array the wolumns of which are the patches extracted from img.
    Args:
    - img: representation of an image as a 2d array
    - path_dim: dimensions of one patch (in pixels)
    - gray: wether to convert or not img to grey levels"""
    
    output = []
    xdim, ydim = patch_dim
    
    #if necessary convert img to gray
    if gray:
        img = rgb2gray(img)
        
    #extract patches
    for i in range(img.shape[0]/xdim):
        for j in range(img.shape[1]/ydim):
            output.append(img[i*xdim:(i+1)*xdim,j*ydim:(j+1)*ydim,].ravel())
            
    return np.array(output).T

# %%
def assemble_patches(patches, original_dim, patch_dim = (8, 8), gray = True):
    """Reassemble patches, given original dimesion of the image
    that was divided into patches"""
    
    #If gray, adapt original dimension
    if gray:
        original_dim = original_dim[:2]
        
    #a list to store all reshaped patches 
    temp = []
    #shortcuts
    xdim, ydim = patch_dim
    
    #reshape all patches (current columns of 'patches' matrix)
    for j in range(patches.shape[1]):
        temp.append(patches[:,j].reshape(patch_dim))
        
    #compute output image
    output_img = np.zeros(original_dim)
    k = 0
    #re-order patches
    for i in range(original_dim[0]/xdim):
        for j in range(original_dim[1]/ydim):
            output_img[i*xdim:(i+1)*xdim,j*ydim:(j+1)*ydim] = temp[k]
            k += 1
            
    return output_img

# %% [markdown]
# Une petite démonstration pour s'assurer que les fonctions fonctionnent bien ;) On remarque une bordure noir sur l'image réassemblée qui vient du fait que les dimensions originales de l'image ne sont pas nécesaairement des multiples des dimensions des patches.

# %%
img = rgb2gray(resize_car(plt.imread(path2db+imgs[1])))
patches = div_patchs(img)
reassembled = assemble_patches(patches, img.shape)
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap = 'gray')
plt.title("Original image")
plt.subplot(1, 2, 2)
plt.imshow(reassembled, cmap = 'gray')
plt.title("Reassembled image")

# %% [markdown]
# Un aperçu de quelques patchs...

# %%
n = 20
plt.figure(figsize=(15, 12))
for i in range(n):
    plt.subplot(4, 5, i)
    plt.imshow(patches[:,np.random.randint(low = 0, high = patches.shape[1])].reshape((8, 8)),
                                           cmap = 'gray')

# %% [markdown]
# Amélioration possible: montrer d'où viennent les patchs dans l'image!

# %% [markdown]
# ### Assemblage de la base totale

# %%
X = np.hstack([div_patchs(resize_car(plt.imread(path2db+name))) for name in imgs[1:]])

# %%
X.shape
# Out:
# (64, 7506)

# %% [markdown]
# On sélectionne au hasard 5000 patchs parmi ceux que l'on généré (c'est visiblement comme cela qu'ils ont fait dans l'article...)

# %%
mask = [True for _ in range(5000)] + [False for _ in range(X.shape[1] - 5000)]

# %%
mask = np.array(mask)
np.random.shuffle(mask)

# %%
Xtrain = X[:,mask]

# %% [markdown]
# ## Construction du dictionnaire

# %%
import imp
ksvd = imp.load_source('ksvd', '../Source/ksvd.py')

# %%
model = ksvd.KSVD(D = (64, 200), K = 10)

# %%
# %%time
model.fit(Xtrain)
# Out:
# Training dictionary over 200 iterations
#  [                  1%                  ] 2 of 200 complete in 5.5 sec
#  [                  1%                  ] 3 of 200 complete in 13.7 sec
#  [                  2%                  ] 4 of 200 complete in 21.8 sec
#  [                  2%                  ] 5 of 200 complete in 29.9 sec
#  [-                 3%                  ] 6 of 200 complete in 38.1 sec
#  [-                 3%                  ] 7 of 200 complete in 46.2 sec
#  [-                 4%                  ] 8 of 200 complete in 54.4 sec
#  [-                 4%                  ] 9 of 200 complete in 62.5 sec
#  [-                 5%                  ] 10 of 200 complete in 70.7 sec
#  [--                5%                  ] 11 of 200 complete in 78.8 sec
#  [--                6%                  ] 12 of 200 complete in 86.9 sec
#  [--                6%                  ] 13 of 200 complete in 95.1 sec
#  [--                7%                  ] 14 of 200 complete in 103.2 sec
#  [--                7%                  ] 15 of 200 complete in 111.3 sec
#  [---               8%                  ] 16 of 200 complete in 119.4 sec
#  [---               8%                  ] 17 of 200 complete in 127.5 sec
#  [---               9%                  ] 18 of 200 complete in 135.7 sec
#  [---               9%                  ] 19 of 200 complete in 143.8 sec
#  [---              10%                  ] 20 of 200 complete in 151.9 sec
#  [---              10%                  ] 21 of 200 complete in 160.0 sec
#  [----             11%                  ] 22 of 200 complete in 168.3 sec
#  [----             11%                  ] 23 of 200 complete in 176.5 sec
#  [----             12%                  ] 24 of 200 complete in 184.6 sec
#  [----             12%                  ] 25 of 200 complete in 192.7 sec
#  [----             13%                  ] 26 of 200 complete in 200.8 sec
#  [-----            13%                  ] 27 of 200 complete in 208.9 sec
#  [-----            14%                  ] 28 of 200 complete in 217.1 sec
#  [-----            14%                  ] 29 of 200 complete in 225.2 sec
#  [-----            15%                  ] 30 of 200 complete in 233.3 sec
#  [-----            15%                  ] 31 of 200 complete in 241.4 sec
#  [------           16%                  ] 32 of 200 complete in 249.6 sec
#  [------           16%                  ] 33 of 200 complete in 257.7 sec
#  [------           17%                  ] 34 of 200 complete in 265.8 sec
#  [------           17%                  ] 35 of 200 complete in 274.0 sec
#  [------           18%                  ] 36 of 200 complete in 282.1 sec
#  [-------          18%                  ] 37 of 200 complete in 290.3 sec
#  [-------          19%                  ] 38 of 200 complete in 298.4 sec
#  [-----------------70%------            ] 141 of 200 complete in 1152.1 sec
#  [-----------------71%------            ] 142 of 200 complete in 1160.3 sec
#  [-----------------71%-------           ] 143 of 200 complete in 1168.5 sec
#  [-----------------72%-------           ] 144 of 200 complete in 1176.5 sec
#  [-----------------72%-------           ] 145 of 200 complete in 1184.6 sec
#  [-----------------73%-------           ] 146 of 200 complete in 1192.6 sec
#  [-----------------73%-------           ] 147 of 200 complete in 1200.7 sec
#  [-----------------74%--------          ] 148 of 200 complete in 1208.7 sec
#  [-----------------74%--------          ] 149 of 200 complete in 1216.8 sec
#  [-----------------75%--------          ] 150 of 200 complete in 1224.8 sec
#  [-----------------75%--------          ] 151 of 200 complete in 1232.9 sec
#  [-----------------76%--------          ] 152 of 200 complete in 1240.9 sec
#  [-----------------76%---------         ] 153 of 200 complete in 1249.0 sec
#  [-----------------77%---------         ] 154 of 200 complete in 1257.0 sec
#  [-----------------77%---------         ] 155 of 200 complete in 1265.0 sec
#  [-----------------78%---------         ] 156 of 200 complete in 1273.1 sec
#  [-----------------78%---------         ] 157 of 200 complete in 1281.1 sec
#  [-----------------79%----------        ] 158 of 200 complete in 1289.2 sec
#  [-----------------79%----------        ] 159 of 200 complete in 1297.2 sec
#  [-----------------80%----------        ] 160 of 200 complete in 1305.3 sec
#  [-----------------80%----------        ] 161 of 200 complete in 1313.3 sec
#  [-----------------81%----------        ] 162 of 200 complete in 1321.4 sec
#  [-----------------81%----------        ] 163 of 200 complete in 1329.4 sec
#  [-----------------82%-----------       ] 164 of 200 complete in 1337.5 sec
#  [-----------------82%-----------       ] 165 of 200 complete in 1345.5 sec
#  [-----------------83%-----------       ] 166 of 200 complete in 1353.6 sec
#  [-----------------83%-----------       ] 167 of 200 complete in 1361.7 sec
#  [-----------------84%-----------       ] 168 of 200 complete in 1369.7 sec
#  [-----------------84%------------      ] 169 of 200 complete in 1377.7 sec
#  [-----------------85%------------      ] 170 of 200 complete in 1385.8 sec
#  [-----------------85%------------      ] 171 of 200 complete in 1393.8 sec
#  [-----------------86%------------      ] 172 of 200 complete in 1401.9 sec
#  [-----------------86%------------      ] 173 of 200 complete in 1409.9 sec
#  [-----------------87%-------------     ] 174 of 200 complete in 1418.0 sec
#  [-----------------87%-------------     ] 175 of 200 complete in 1426.0 sec
#  [-----------------88%-------------     ] 176 of 200 complete in 1434.1 sec
#  [-----------------88%-------------     ] 177 of 200 complete in 1442.1 sec
#  [-----------------89%-------------     ] 178 of 200 complete in 1450.2 sec
#  [-----------------89%--------------    ] 179 of 200 complete in 1458.2 sec
#  [-----------------90%--------------    ] 180 of 200 complete in 1466.3 sec
#  [-----------------90%--------------    ] 181 of 200 complete in 1474.4 sec
#  [-----------------91%--------------    ] 182 of 200 complete in 1482.4 sec
#  [-----------------91%--------------    ] 183 of 200 complete in 1490.5 sec
#  [-----------------92%--------------    ] 184 of 200 complete in 1498.5 sec
#  [-----------------92%---------------   ] 185 of 200 complete in 1506.6 sec
#  [-----------------93%---------------   ] 186 of 200 complete in 1514.7 sec
#  [-----------------93%---------------   ] 187 of 200 complete in 1522.7 sec
#  [-----------------94%---------------   ] 188 of 200 complete in 1530.8 sec
#  [-----------------94%---------------   ] 189 of 200 complete in 1538.9 sec
#  [-----------------95%----------------  ] 190 of 200 complete in 1546.9 sec
#  [-----------------95%----------------  ] 191 of 200 complete in 1555.0 sec
#  [-----------------96%----------------  ] 192 of 200 complete in 1563.0 sec
#  [-----------------96%----------------  ] 193 of 200 complete in 1571.1 sec
#  [-----------------97%----------------  ] 194 of 200 complete in 1579.1 sec
#  [-----------------97%----------------- ] 195 of 200 complete in 1587.1 sec
#  [-----------------98%----------------- ] 196 of 200 complete in 1595.2 sec
#  [-----------------98%----------------- ] 197 of 200 complete in 1603.3 sec
#  [-----------------99%----------------- ] 198 of 200 complete in 1611.3 sec
#  [-----------------99%----------------- ] 199 of 200 complete in 1619.3 sec
#  [-----------------100%-----------------] 200 of 200 complete in 1627.4 sec
#  [-----------------100%-----------------] 201 of 200 complete in 1635.4 sec
#    Done!
# CPU times: user 27min 8s, sys: 5.27 s, total: 27min 13s
# Wall time: 27min 15s

# %%
#Comme ce genre de calcul prend pas mal de temps,
#autant sauvegarder les résultats
import pickle
with open ('model.pickle', 'wb') as f:
    pickle.dump(model, f)

# %% [markdown]
# ### Test sur une image intégrale...

# %% [markdown]
# #### Sans bruit (commençons lentement mais surement)

# %%
img = resize_car(plt.imread(path2db+imgs[0]))
plt.imshow(img)

# %%
pp = div_patchs(img)
gamma = model.sparse_rep(pp)
new_patches = model.D.dot(gamma)
resulting_img = assemble_patches(new_patches, img.shape[:2])

# %%
plt.imshow(resulting_img, cmap = 'gray')

# %%
horse = plt.imread('/home/paul/StatApp/Database/Horses/00004.jpg')
pp = div_patchs(horse)
gamma = model.sparse_rep(pp)
new_patches = model.D.dot(gamma)
resulting_img = assemble_patches(new_patches, horse.shape[:2])

plt.figure(figsize=(10,8))
plt.subplot(121)
plt.imshow(resulting_img, cmap = 'gray')
plt.subplot(122)
plt.imshow(horse)

# %% [markdown]
# J'ai bien peur que tel que nous le faisons marcher, l'algorithme ne capture aucune information sur le type d'images avec lequel nous construisons le dictionnaire...

# %% [markdown]
# #### Avec bruit (soyons fous)

# %% [markdown]
# On commence par bruiter très simplement une image

# %%
mask = np.random.random(img.shape[:2])
#noisy = rgb2gray(img + .5*img.std()*np.random.random(img.shape))
noisy = img.copy()
noisy[(mask > .9)] = 0

# %%
pp = div_patchs(noisy)
gamma = model.sparse_rep(pp)
new_patches = model.D.dot(gamma)
resulting_img = assemble_patches(new_patches, img.shape[:2])

# %%
from skimage.filter import denoise_bilateral

plt.figure(figsize=(15, 8))
plt.subplot(131)
plt.imshow(resulting_img, cmap = 'gray')
plt.title("K-SVD denoising")
plt.subplot(132)
plt.imshow(denoise_bilateral(noisy), cmap = 'gray')
plt.title("Bilateral denoisng")
plt.subplot(133)
plt.imshow(noisy, cmap = 'gray')
plt.title("Noisy image")

# %% [markdown]
# Bon il y a encore sans doute des choses à améliorer... La principale perspective d'amélioration réside sans doute dans taille des patchs, qui me semble trop petite par rapport à la taille de l'image. Pendant que j'y pense, il faudra quand même faire un test avec un dictionnaire aléatoire pour voir si on n'est pas dans l'illusion la plus totale :) Et un autre test, plus proche de l'article, cette fois en enlevant des pixels.
