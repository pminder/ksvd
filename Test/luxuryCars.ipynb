# %% [markdown]
# # K-SVD et voitures de luxe...

# %% [markdown]
# Ce notebook se présente comme une proof of concept de l'utilisation que l'on peut faire du traitement des images par représentation sparse en général et de l'algorithme k-svd en particulier.
#
# La méthode utilisée est la suivante:
# - on crée un dictionnaire à partir d'une base de données initiales constituée de petites images (ou patchs) issus d'une séri d'images représentant des voitures de luxe
# - on choisit une image nouvelle image de voiture sur internet que l'on bruite artificiellement
# - on calcule ensuite sa représentation sparse grâce à un algorithme du type batch-OMP et on voit ce que ça donne !

# %% [markdown]
# ## Constitution de la base d'entraînement

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.color import rgb2gray
# %matplotlib inline

# %%
path2db = "../Database/Cars/"

# %% [markdown]
# Un exemple d'image au hasard, juste pour ce faire une idée:

# %%
imgs = !ls $path2db
plt.imshow(plt.imread(path2db+imgs[1]))
plt.title("Un exemple de voiture")

# %% [markdown]
# ### Fonction pour redimensioner les images

# %% [markdown]
# Sans cette fonction, on risque de générer trop de patchs. Dans un premier temps, je préfère diminuer un peu la taille des images. On verra ensuite si on peut lever cette restriction.

# %%
from skimage.transform import rescale

# %%
def resize_car(img):
    """Allow at most images of size (250, 250)"""
    x, y = img.shape[0], img.shape[1]
    if max(x, y) > 250:
        l = 250./max(x,y)
        img = rescale(img, l)
    return img

# %% [markdown]
# ### Division en patchs

# %%
def div_patchs(img, patch_dim = (8, 8), gray = True):
    """Return a 2d array the columns of which are the patches extracted from img.
    Args:
    - img: representation of an image as a 2d array
    - path_dim: dimensions of one patch (in pixels)
    - gray: wether to convert or not img to grey levels"""
    
    output = []
    xdim, ydim = patch_dim
    
    #if necessary convert img to gray
    if gray:
        img = rgb2gray(img)
        
    #extract patches
    for i in range(img.shape[0]/xdim):
        for j in range(img.shape[1]/ydim):
            output.append(img[i*xdim:(i+1)*xdim,j*ydim:(j+1)*ydim,].ravel())
            
    return np.array(output).T

# %%
def assemble_patches(patches, original_dim, patch_dim = (8, 8), gray = True):
    """Reassemble patches, given original dimesion of the image
    that was divided into patches"""
    
    #If gray, adapt original dimension
    if gray:
        original_dim = original_dim[:2]
        
    #a list to store all reshaped patches 
    temp = []
    #shortcuts
    xdim, ydim = patch_dim
    
    #reshape all patches (current columns of 'patches' matrix)
    for j in range(patches.shape[1]):
        temp.append(patches[:,j].reshape(patch_dim))
        
    #compute output image
    output_img = np.zeros(original_dim)
    k = 0
    #re-order patches
    for i in range(original_dim[0]/xdim):
        for j in range(original_dim[1]/ydim):
            output_img[i*xdim:(i+1)*xdim,j*ydim:(j+1)*ydim] = temp[k]
            k += 1
            
    return output_img

# %% [markdown]
# Une petite démonstration pour s'assurer que les fonctions fonctionnent bien ;) On remarque une bordure noir sur l'image réassemblée qui vient du fait que les dimensions originales de l'image ne sont pas nécesaairement des multiples des dimensions des patches.

# %%
img = rgb2gray(resize_car(plt.imread(path2db+imgs[1])))
patches = div_patchs(img)
reassembled = assemble_patches(patches, img.shape)
plt.figure(figsize=(15, 5))
plt.subplot(1, 2, 1)
plt.imshow(img, cmap = 'gray')
plt.title("Original image")
plt.subplot(1, 2, 2)
plt.imshow(reassembled, cmap = 'gray')
plt.title("Reassembled image")

# %% [markdown]
# Un aperçu de quelques patchs...

# %%
n = 20
plt.figure(figsize=(15, 12))
for i in range(n):
    plt.subplot(4, 5, i)
    plt.imshow(patches[:,np.random.randint(low = 0, high = patches.shape[1])].reshape((8, 8)),
                                           cmap = 'gray')

# %% [markdown]
# Amélioration possible: montrer d'où viennent les patchs dans l'image!

# %% [markdown]
# ### Assemblage de la base totale

# %%
X = np.hstack([div_patchs(resize_car(plt.imread(path2db+name))) for name in imgs[1:]])

# %%
X.shape
# Out:
# (64, 21545)

# %% [markdown]
# On sélectionne au hasard 5000 patchs parmi ceux que l'on généré (c'est visiblement comme cela qu'ils ont fait dans l'article...)

# %%
mask = [True for _ in range(5000)] + [False for _ in range(X.shape[1] - 5000)]

# %%
mask = np.array(mask)
np.random.shuffle(mask)

# %%
Xtrain = X[:,mask]

# %% [markdown]
# ## Construction du dictionnaire

# %%
import imp
ksvd = imp.load_source('ksvd', '../Source/ksvd.py')

# %%
model = ksvd.KSVD(D = (64, 200), K = 10)

# %%
# %%time
model.fit(Xtrain)
# Out:
# Training dictionary over 200 iterations
#  [                  1%                  ] 2 of 200 complete in 6.1 sec
#  [                  1%                  ] 3 of 200 complete in 14.4 sec
#  [                  2%                  ] 4 of 200 complete in 22.5 sec
#  [                  2%                  ] 5 of 200 complete in 30.7 sec
#  [-                 3%                  ] 6 of 200 complete in 38.9 sec
#  [-                 3%                  ] 7 of 200 complete in 47.1 sec
#  [-                 4%                  ] 8 of 200 complete in 55.3 sec
#  [-                 4%                  ] 9 of 200 complete in 63.5 sec
#  [-                 5%                  ] 10 of 200 complete in 71.7 sec
#  [--                5%                  ] 11 of 200 complete in 79.9 sec
#  [--                6%                  ] 12 of 200 complete in 88.1 sec
#  [--                6%                  ] 13 of 200 complete in 96.3 sec
#  [--                7%                  ] 14 of 200 complete in 104.4 sec
#  [--                7%                  ] 15 of 200 complete in 112.7 sec
#  [---               8%                  ] 16 of 200 complete in 121.0 sec
#  [---               8%                  ] 17 of 200 complete in 129.3 sec
#  [---               9%                  ] 18 of 200 complete in 137.5 sec
#  [---               9%                  ] 19 of 200 complete in 145.8 sec
#  [---              10%                  ] 20 of 200 complete in 154.1 sec
#  [---              10%                  ] 21 of 200 complete in 162.4 sec
#  [----             11%                  ] 22 of 200 complete in 170.6 sec
#  [----             11%                  ] 23 of 200 complete in 178.9 sec
#  [----             12%                  ] 24 of 200 complete in 187.2 sec
#  [----             12%                  ] 25 of 200 complete in 195.6 sec
#  [----             13%                  ] 26 of 200 complete in 203.8 sec
#  [-----            13%                  ] 27 of 200 complete in 212.1 sec
#  [-----            14%                  ] 28 of 200 complete in 220.3 sec
#  [-----            14%                  ] 29 of 200 complete in 228.6 sec
#  [-----            15%                  ] 30 of 200 complete in 236.8 sec
#  [-----------------62%---               ] 125 of 200 complete in 1024.3 sec
#  [-----------------63%---               ] 126 of 200 complete in 1032.6 sec
#  [-----------------63%----              ] 127 of 200 complete in 1040.8 sec
#  [-----------------64%----              ] 128 of 200 complete in 1049.0 sec
#  [-----------------64%----              ] 129 of 200 complete in 1057.2 sec
#  [-----------------65%----              ] 130 of 200 complete in 1065.4 sec
#  [-----------------65%----              ] 131 of 200 complete in 1073.6 sec
#  [-----------------66%-----             ] 132 of 200 complete in 1081.9 sec
#  [-----------------66%-----             ] 133 of 200 complete in 1090.1 sec
#  [-----------------67%-----             ] 134 of 200 complete in 1098.3 sec
#  [-----------------67%-----             ] 135 of 200 complete in 1106.6 sec
#  [-----------------68%-----             ] 136 of 200 complete in 1114.7 sec
#  [-----------------68%------            ] 137 of 200 complete in 1123.0 sec
#  [-----------------69%------            ] 138 of 200 complete in 1131.2 sec
#  [-----------------69%------            ] 139 of 200 complete in 1139.4 sec
#  [-----------------70%------            ] 140 of 200 complete in 1147.6 sec
#  [-----------------70%------            ] 141 of 200 complete in 1155.8 sec
#  [-----------------71%------            ] 142 of 200 complete in 1164.0 sec
#  [-----------------71%-------           ] 143 of 200 complete in 1172.2 sec
#  [-----------------72%-------           ] 144 of 200 complete in 1180.4 sec
#  [-----------------72%-------           ] 145 of 200 complete in 1188.6 sec
#  [-----------------73%-------           ] 146 of 200 complete in 1196.8 sec
#  [-----------------73%-------           ] 147 of 200 complete in 1205.0 sec
#  [-----------------74%--------          ] 148 of 200 complete in 1213.2 sec
#  [-----------------74%--------          ] 149 of 200 complete in 1221.4 sec
#  [-----------------75%--------          ] 150 of 200 complete in 1229.6 sec
#  [-----------------75%--------          ] 151 of 200 complete in 1237.7 sec
#  [-----------------76%--------          ] 152 of 200 complete in 1245.9 sec
#  [-----------------76%---------         ] 153 of 200 complete in 1254.1 sec
#  [-----------------77%---------         ] 154 of 200 complete in 1262.3 sec
#  [-----------------77%---------         ] 155 of 200 complete in 1270.5 sec
#  [-----------------78%---------         ] 156 of 200 complete in 1278.7 sec
#  [-----------------78%---------         ] 157 of 200 complete in 1286.9 sec
#  [-----------------79%----------        ] 158 of 200 complete in 1295.0 sec
#  [-----------------79%----------        ] 159 of 200 complete in 1303.2 sec
#  [-----------------80%----------        ] 160 of 200 complete in 1311.4 sec
#  [-----------------80%----------        ] 161 of 200 complete in 1319.6 sec
#  [-----------------81%----------        ] 162 of 200 complete in 1327.8 sec
#  [-----------------81%----------        ] 163 of 200 complete in 1336.0 sec
#  [-----------------82%-----------       ] 164 of 200 complete in 1344.2 sec
#  [-----------------82%-----------       ] 165 of 200 complete in 1352.4 sec
#  [-----------------83%-----------       ] 166 of 200 complete in 1360.6 sec
#  [-----------------83%-----------       ] 167 of 200 complete in 1368.8 sec
#  [-----------------84%-----------       ] 168 of 200 complete in 1377.0 sec
#  [-----------------84%------------      ] 169 of 200 complete in 1385.3 sec
#  [-----------------85%------------      ] 170 of 200 complete in 1393.5 sec
#  [-----------------85%------------      ] 171 of 200 complete in 1401.7 sec
#  [-----------------86%------------      ] 172 of 200 complete in 1409.9 sec
#  [-----------------86%------------      ] 173 of 200 complete in 1418.0 sec
#  [-----------------87%-------------     ] 174 of 200 complete in 1426.2 sec
#  [-----------------87%-------------     ] 175 of 200 complete in 1434.4 sec
#  [-----------------88%-------------     ] 176 of 200 complete in 1442.6 sec
#  [-----------------88%-------------     ] 177 of 200 complete in 1450.8 sec
#  [-----------------89%-------------     ] 178 of 200 complete in 1459.0 sec
#  [-----------------89%--------------    ] 179 of 200 complete in 1467.2 sec
#  [-----------------90%--------------    ] 180 of 200 complete in 1475.4 sec
#  [-----------------90%--------------    ] 181 of 200 complete in 1483.8 sec
#  [-----------------91%--------------    ] 182 of 200 complete in 1492.2 sec
#  [-----------------91%--------------    ] 183 of 200 complete in 1500.7 sec
#  [-----------------92%--------------    ] 184 of 200 complete in 1509.3 sec
#  [-----------------92%---------------   ] 185 of 200 complete in 1518.2 sec
#  [-----------------93%---------------   ] 186 of 200 complete in 1526.6 sec
#  [-----------------93%---------------   ] 187 of 200 complete in 1534.9 sec
#  [-----------------94%---------------   ] 188 of 200 complete in 1543.2 sec
#  [-----------------94%---------------   ] 189 of 200 complete in 1551.9 sec
#  [-----------------95%----------------  ] 190 of 200 complete in 1560.3 sec
#  [-----------------95%----------------  ] 191 of 200 complete in 1568.9 sec
#  [-----------------96%----------------  ] 192 of 200 complete in 1577.3 sec
#  [-----------------96%----------------  ] 193 of 200 complete in 1585.8 sec
#  [-----------------97%----------------  ] 194 of 200 complete in 1594.4 sec
#  [-----------------97%----------------- ] 195 of 200 complete in 1603.0 sec
#  [-----------------98%----------------- ] 196 of 200 complete in 1611.5 sec
#  [-----------------98%----------------- ] 197 of 200 complete in 1619.9 sec
#  [-----------------99%----------------- ] 198 of 200 complete in 1628.3 sec
#  [-----------------99%----------------- ] 199 of 200 complete in 1636.7 sec
#  [-----------------100%-----------------] 200 of 200 complete in 1645.1 sec
#  [-----------------100%-----------------] 201 of 200 complete in 1653.5 sec
#    Done!
# CPU times: user 27min 20s, sys: 11.6 s, total: 27min 31s
# Wall time: 27min 33s

# %%
#Comme ce genre de calcul prend pas mal de temps,
#autant sauvegarder les résultats
import pickle
with open ('model.pickle', 'wb') as f:
    pickle.dump(model, f)

# %%
#Pour charger le modèle sans avoir à le ré-entraîner
import pickle
with open('model.pickle', 'rb') as f:
    model = pickle.load(f)

# %% [markdown]
# ### Test sur une image intégrale...

# %% [markdown]
# #### Sans bruit (commençons lentement mais surement)

# %%
img = resize_car(plt.imread(path2db+imgs[0]))
plt.imshow(img)

# %%
pp = div_patchs(img)
gamma = model.sparse_rep(pp)
new_patches = model.D.dot(gamma)
resulting_img = assemble_patches(new_patches, img.shape[:2])

# %%
plt.imshow(resulting_img, cmap = 'gray')

# %% [markdown]
# #### Avec bruit

# %% [markdown]
# Tout d'abord on définit une fonction permettant de calculer l'erreur de reconstruction (on utilise exactement la fonction de l'article):
# $$\sqrt{||B - \tilde{B}||^2 _F /64}$$
# avec $B$ l'image initiale non bruitée et $\tilde{B}$ l'image débruitée.

# %%
def rec_err(B, B_):
    """Returns mean reconstrution error for all patches.
    Args: - B original image with no noise
          - B_ denoised image
    """
    
    return np.linalg.norm(div_patchs(B) - div_patchs(B_), axis=0).mean()/8.

# %% [markdown]
# On commence par bruiter très simplement une image

# %%
mask = np.random.random(img.shape[:2])
noisy = img.copy()
noisy[(mask > .9)] = 0

# %%
pp = div_patchs(noisy)
new_patches = model.denoise_patches(pp, .01)
resulting_img = assemble_patches(new_patches, img.shape[:2])

# %%
from skimage.filter import denoise_bilateral

plt.figure(figsize=(15, 8))
plt.subplot(131)
plt.imshow(resulting_img, cmap = 'gray')
plt.title("K-SVD denoising (err: {})".format(rec_err(rgb2gray(img), resulting_img)))
plt.subplot(132)
plt.imshow(denoise_bilateral(noisy), cmap = 'gray')
plt.title("Bilateral denoisng (err: {})".format(rec_err(rgb2gray(img), 
                                                    rgb2gray(denoise_bilateral(noisy)))))
plt.subplot(133)
plt.imshow(noisy, cmap = 'gray')
plt.title("Noisy image")

# %% [markdown]
# Un autre essai avec plus de bruit...

# %%
mask = np.random.random(img.shape[:2])
noisy = img.copy()
noisy[(mask > .6)] = 0
pp = div_patchs(noisy)
new_patches = model.denoise_patches(pp, .01)
resulting_img = assemble_patches(new_patches, img.shape[:2])

# %%
plt.figure(figsize=(10, 8))
plt.subplot(121)
plt.imshow(resulting_img, cmap = 'gray')
plt.title("K-SVD denoising (err: {})".format(rec_err(rgb2gray(img), resulting_img)))
plt.subplot(122)
plt.imshow(noisy, cmap = 'gray')
plt.title("Noisy image")

# %% [markdown]
# Pour finir, une courbe représentant l'erreur de reconstitution en fonction de la densité des pixels supprimés.

# %%
xx = [x/10. for x in range(1, 10)]
RMSE = []

for x in xx:
    #On construit une image bruitée
    mask = np.random.random(img.shape[:2])
    noisy = img.copy()
    noisy[(mask < x)] = 0
    pp = div_patchs(noisy)
    new_patches = model.denoise_patches(pp, .01)
    resulting_img = assemble_patches(new_patches, img.shape[:2])
    
    RMSE.append(rec_err(resulting_img, rgb2gray(img)))

# %%
plt.plot(xx, RMSE)
plt.title(u"Qualité de reconstruction")
plt.xlabel(u"Ratio de pixels corrompus")
plt.ylabel(u"Erreur de reconstruction")
plt.axis([.1, .9, 0., .55])
# Out:
# [0.1, 0.9, 0.0, 0.55]

# %% [markdown]
# Bien que l'on obtienne des ratios du même ordre de grandeur que dans l'article, les nôtres sont un peu moins bons... Cela peut être dû:
# - au faut que notre dictionnaire contienne nettement moins d'atoms
# - au fait que nous avons construit notre dictionnaire à partir d'un nombre plus faible de patches
